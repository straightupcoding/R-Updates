# %% [markdown]
# Data Science Fundamentals: R |
# [Table of Contents](../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Module 14. [tidyverse](./00.ipynb) | [R Markdown](./01.ipynb) | [R + Shiny App](./02.ipynb) | [Basic Visualization](./03.ipynb) | [Tibbles](./04.ipynb)  | [ggplot2](./05.ipynb) | [Statistical Transformations](./06.ipynb) | [Exercises](./07.ipynb)

# %% [markdown]
# # [tidyverse](https://www.tidyverse.org/)

# %% [markdown]
# ![tidyverse](images/slides1.png)

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/4.0/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ![tidyverse](images/slides2.png)

# %% [markdown]
# ## Loading JSON Files

# %%
install.packages("rjson")
# Out:
# Installing package into ‘/usr/local/lib/R/4.0/site-library’
# (as ‘lib’ is unspecified)

# %%
# Load the package required to read JSON files.
library("rjson")

# Give the input file name to the function.
result <- fromJSON(file = "dataSets/input.json")

# Print the result.
print(result)
# Out:
# $ID
# [1] "1" "2" "3" "4" "5" "6" "7" "8"
#
# $Name
# [1] "Rick"     "Dan"      "Michelle" "Ryan"     "Gary"     "Nina"     "Simon"
# [8] "Guru"
#
# $Salary
# [1] "623.3"  "515.2"  "611"    "729"    "843.25" "578"    "632.8"  "722.5"
#
# $StartDate
# [1] "1/1/2012"   "9/23/2013"  "11/15/2014" "5/11/2014"  "3/27/2015"
# [6] "5/21/2013"  "7/30/2013"  "6/17/2014"
#
# $Dept
# [1] "IT"         "Operations" "IT"         "HR"         "Finance"
# [6] "IT"         "Operations" "Finance"

# %%
library("rjson")

result <- fromJSON(file = "dataSets/input.json")

json_data_frame <- as.data.frame(result)

# %%
json_data_frame
# Out:
#   ID Name     Salary StartDate  Dept
# 1 1  Rick     623.3  1/1/2012   IT
# 2 2  Dan      515.2  9/23/2013  Operations
# 3 3  Michelle 611    11/15/2014 IT
# 4 4  Ryan     729    5/11/2014  HR
# 5 5  Gary     843.25 3/27/2015  Finance
# 6 6  Nina     578    5/21/2013  IT
# 7 7  Simon    632.8  7/30/2013  Operations
# 8 8  Guru     722.5  6/17/2014  Finance

# %%
install.packages("RJSONIO")
# Out:
# The downloaded binary packages are in
# 	/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T//RtmpPkWYlX/downloaded_packages

# %%
library(RJSONIO)
# from the website
foodMarketsRaw <- fromJSON("https://data.ny.gov/api/views/9a8c-vfzj/rows.json?accessType=DOWNLOAD")
# Out:
# Attaching package: ‘RJSONIO’
#
#
# The following objects are masked from ‘package:rjson’:
#
#     fromJSON, toJSON

# %%
foodMarkets <- foodMarketsRaw[['data']]

# name the food market 1
foodMarkets[[1]][[14]]

# name of food market 2
foodMarkets[[2]][[14]]

fmNames <- sapply(foodMarkets, function(x) x[[14]])
head(fmNames)
# Out:
# [1] "HOGG DAIRY LAKEVIEW    "
# [1] "TOPS 586               "
# [1] "HOGG DAIRY LAKEVIEW    " "TOPS 586               "
# [3] "STEWARTS SHOP 264      " "ACCORD KWIK MART       "
# [5] "YESHIVA FARM SETTLEMENT" "GODIVA CHOCOLATIER  251"

# %%
install.packages("gdata")
# Out:
# also installing the dependency ‘gtools’
# The downloaded binary packages are in
# 	/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T//RtmpmHitwx/downloaded_packages

# %%
# for the trim function
library(gdata)
grabInfo <- function(var){
  print(paste("Variable", var, sep=" "))
  sapply(foodMarkets, function(x) returnData(x, var))
}

returnData <- function(x, var){
  if(!is.null( x[[var]])){
  	return( trim(x[[var]]))
  	}else{
  		return(NA)
  	}
  }


# do the extraction and assembly
 fmDataDF <- data.frame(sapply(1:22, grabInfo), stringsAsFactors=FALSE)
# Out:
# gdata: read.xls support for 'XLS' (Excel 97-2004) files ENABLED.
#
#
#
# gdata: read.xls support for 'XLSX' (Excel 2007+) files ENABLED.
#
#
# Attaching package: ‘gdata’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     keep
#
#
# The following object is masked from ‘package:stats’:
#
#     nobs
#
#
# The following object is masked from ‘package:utils’:
#
#     object.size
#
#
# The following object is masked from ‘package:base’:
#
#     startsWith
# [1] "Variable 1"
# [1] "Variable 2"
# [1] "Variable 3"
# [1] "Variable 4"
# [1] "Variable 5"
# [1] "Variable 6"
# [1] "Variable 7"
# [1] "Variable 8"
# [1] "Variable 9"
# [1] "Variable 10"
# [1] "Variable 11"
# [1] "Variable 12"
# [1] "Variable 13"
# [1] "Variable 14"
# [1] "Variable 15"
# [1] "Variable 16"
# [1] "Variable 17"
# [1] "Variable 18"
# [1] "Variable 19"
# [1] "Variable 20"
# [1] "Variable 21"
# [1] "Variable 22"

# %%
fmDataDF
# Out:
#       X1                 X2                                   X3 X4         X5
# 1     row-qa3g_84hp_jtun 00000000-0000-0000-01D1-48931FF87197 0  1594246201 NA
# 2     row-zuk9_93ea~ztca 00000000-0000-0000-102A-33B0131693CD 0  1594246201 NA
# 3     row-g2vc.3ryg_qbu3 00000000-0000-0000-D5BD-471F41F56F7A 0  1594246201 NA
# 4     row-936y_z6pt~wpsg 00000000-0000-0000-D1C4-E87042CF44DA 0  1594246201 NA
# 5     row-2ppd~zaqv_ztvt 00000000-0000-0000-73BA-8CFEC0EFD238 0  1594246201 NA
# 6     row-xtqc~arr4~ew5i 00000000-0000-0000-CF29-9EF13E7B839A 0  1594246201 NA
# 7     row-67au.wasu_vxsh 00000000-0000-0000-F10C-D898717F8E22 0  1594246201 NA
# 8     row-yiym-nxr2_b2q3 00000000-0000-0000-663A-E073C4F52399 0  1594246201 NA
# 9     row-ubym-iyrh-855b 00000000-0000-0000-7F2C-6F6103329B54 0  1594246201 NA
# 10    row-xy9c_5twp~tnjy 00000000-0000-0000-D37B-E72AB6A7DA4F 0  1594246201 NA
# 11    row-dgqt.xn8m_cmi3 00000000-0000-0000-FE1B-A4A576F26FC6 0  1594246201 NA
# 12    row-9vhp.imeg_ywaa 00000000-0000-0000-EC71-28B85AD259D7 0  1594246201 NA
# 13    row-v7vn_7bzb-bpkr 00000000-0000-0000-CCBF-CE2DC521636A 0  1594246201 NA
# 14    row-qyaj-fyrc.awme 00000000-0000-0000-CC98-D7B3CCC169A5 0  1594246201 NA
# 15    row-j5bz_8siw.bf6y 00000000-0000-0000-BDB0-94BFBD14E6FA 0  1594246201 NA
# 16    row-ns84-w5x2_8zff 00000000-0000-0000-33C9-8A55E5916FF4 0  1594246201 NA
# 17    row-gks2~28hb_m95v 00000000-0000-0000-CFF5-C25108C3DA48 0  1594246201 NA
# 18    row-5zsr_6e96.8u99 00000000-0000-0000-A1A0-DDAF88FFD6B0 0  1594246201 NA
# 19    row-ik45_dbf9-if2i 00000000-0000-0000-7274-0B478DEDC1FB 0  1594246201 NA
# 20    row-tbpp.a54y-d4sb 00000000-0000-0000-0525-F798A6BF8108 0  1594246201 NA
# 21    row-n478.b5ev-8gea 00000000-0000-0000-C749-E0636B5DFA98 0  1594246201 NA
# 22    row-ux7i.guzh~bard 00000000-0000-0000-0D1F-C53A1620EF9B 0  1594246201 NA
# 23    row-gcyt.5jz4.h8pe 00000000-0000-0000-C205-CC613078E54F 0  1594246201 NA
# 24    row-g5gy~w2ae_cab2 00000000-0000-0000-5B99-EC4860440E98 0  1594246201 NA
# 25    row-2mqp-933f.y59b 00000000-0000-0000-9C3C-F426F79C21F6 0  1594246201 NA
# 26    row-pkdn~jqqj_4gfc 00000000-0000-0000-B57F-99F9FDC16667 0  1594246201 NA
# 27    row-chuk-bkvi-gpvv 00000000-0000-0000-DE57-9A8F8D59EE1D 0  1594246201 NA
# 28    row-5tmf_rwhf~mvsk 00000000-0000-0000-514D-78C4F1E4D644 0  1594246201 NA
# 29    row-jivu.xba2-98hm 00000000-0000-0000-CDAA-FCDB3B1C5B13 0  1594246201 NA
# 30    row-cqxi.r92b.vd5g 00000000-0000-0000-7556-FE583028D55B 0  1594246201 NA
# ⋮     ⋮                  ⋮                                    ⋮  ⋮          ⋮
# 28307 row-f9vr~fcxj~igvx 00000000-0000-0000-CB1D-61E6E5AD866A 0  1594246201 NA
# 28308 row-9im2.yy6s-wce8 00000000-0000-0000-CEFC-F427B06745D1 0  1594246201 NA
# 28309 row-mqsf.x7xq.i4s8 00000000-0000-0000-BCB2-C6770F4AF9C9 0  1594246201 NA
# 28310 row-6zt8-5sn2~76x2 00000000-0000-0000-533A-5175F53BC17D 0  1594246201 NA
# 28311 row-fz3p_pzep~mh7t 00000000-0000-0000-9AE9-3AB2C65BE52F 0  1594246201 NA
# 28312 row-r9j6~k8me-adjq 00000000-0000-0000-85ED-62A8D3D2E2DF 0  1594246201 NA
# 28313 row-8j4g.eeg7-icsu 00000000-0000-0000-9C97-58A063FD0133 0  1594246201 NA
# 28314 row-px62~9qyi~fyvz 00000000-0000-0000-3EA0-FC18FED742AF 0  1594246201 NA
# 28315 row-t8uf~b3gd_erym 00000000-0000-0000-0D92-E5EC9C8CCCEA 0  1594246201 NA
# 28316 row-ziwu.y8az~sfh7 00000000-0000-0000-32BE-3307B0E85D9D 0  1594246201 NA
# 28317 row-7kk4.dhfc-dzsj 00000000-0000-0000-57BE-245A18B2DE47 0  1594246201 NA
# 28318 row-4chs.3khw~qe6w 00000000-0000-0000-B0D0-E016BDDD7DEC 0  1594246201 NA
# 28319 row-px9m.cx8b.4rua 00000000-0000-0000-C9D2-0827D0A94E17 0  1594246201 NA
# 28320 row-ba7n.vux7-gd8y 00000000-0000-0000-B618-719D6CA5D529 0  1594246201 NA
# 28321 row-fycn-22en.fjnr 00000000-0000-0000-3495-06D18F10C4AD 0  1594246201 NA
# 28322 row-jqxp_qk2e_uxwu 00000000-0000-0000-55D1-77F89AB4DC4C 0  1594246201 NA
# 28323 row-d9f6-4mxj_b8fw 00000000-0000-0000-E5F2-CA118390F119 0  1594246201 NA
# 28324 row-9fv6~i9ha.s7cs 00000000-0000-0000-9652-7D8176B71304 0  1594246201 NA
# 28325 row-zder.u5tm.ns8f 00000000-0000-0000-A26F-E72F4EEB34F9 0  1594246201 NA
# 28326 row-p7sk.yrjz.iszq 00000000-0000-0000-780D-EFCA1C9DD23D 0  1594246201 NA
# 28327 row-t6ka.av56~tikb 00000000-0000-0000-2567-C498C129C5C9 0  1594246201 NA
# 28328 row-iatn-iu2i_62xx 00000000-0000-0000-3D82-9B8FAAC189ED 0  1594246201 NA
# 28329 row-pr2p.3q6z~4czd 00000000-0000-0000-4DC4-FC46C0D04814 0  1594246201 NA
# 28330 row-zzuc~we5t.d85i 00000000-0000-0000-C89E-ADA6D4A8040A 0  1594246201 NA
# 28331 row-msnd.xn93-6ujj 00000000-0000-0000-D736-4EEAC12149FC 0  1594246201 NA
# 28332 row-dit9_z6uv.pjkx 00000000-0000-0000-8267-9BAFD154F5AD 0  1594246201 NA
# 28333 row-futn_ca9g~ewbg 00000000-0000-0000-93B7-F48AC447F67B 0  1594246201 NA
# 28334 row-dr32-i5k4~kpfx 00000000-0000-0000-A1B4-662B053CE878 0  1594246201 NA
# 28335 row-kyf3-rcmy.nqjq 00000000-0000-0000-7BAC-1A130244A541 0  1594246201 NA
# 28336 row-2hzd_kyjr.nqy8 00000000-0000-0000-ED5F-47C9BEC819AB 0  1594246201 NA
#       X6         X7 X8  X9          X10    ⋯ X13
# 1     1594246325 NA { } Chenango    080033 ⋯ STEWARTS SHOPS CORP
# 2     1594246325 NA { } Clinton     095255 ⋯ CHURCH OIL CO INC
# 3     1594246325 NA { } Columbia    105169 ⋯ CUMBERLAND FARMS INC
# 4     1594246325 NA { } Erie        148458 ⋯ DELTA SONIC CAR WASH SYSTEMS INC
# 5     1594246325 NA { } Greene      190145 ⋯ SYDJESKO LLC
# 6     1594246325 NA { } Niagara     728621 ⋯ DOLGENCORP OF NEW YORK INC
# 7     1594246325 NA { } Oneida      300671 ⋯ TOPS PT LLC
# 8     1594246325 NA { } Orange      335779 ⋯ STEWARTS SHOPS CORP
# 9     1594246325 NA { } Otsego      360200 ⋯ TOPS PT LLC
# 10    1594246325 NA { } Saratoga    415643 ⋯ DRAKE PETROLEUM CO INC
# 11    1594246325 NA { } Saratoga    720191 ⋯ J LAIACONA LLC
# 12    1594246325 NA { } Schoharie   731423 ⋯ NORTH CREEK ENTERPRISES LLC
# 13    1594246325 NA { } Ulster      510443 ⋯ HARI KRUPA LLC
# 14    1594246325 NA { } Ulster      515283 ⋯ CUMBERLAND FARMS INC
# 15    1594246325 NA { } Ulster      515762 ⋯ PETERS APPLE BIN FARM MARKET INC
# 16    1594246325 NA { } Ulster      724204 ⋯ DOLGENCORP OF NEW YORK INC
# 17    1594246325 NA { } Yates       703932 ⋯ ELLIOTT JOHN
# 18    1594246325 NA { } Bronx       601880 ⋯ ROBT T COCHRAN&CO INC
# 19    1594246325 NA { } Kings       610706 ⋯ WILKLOW FRED
# 20    1594246392 NA { } New York    624199 ⋯ MESSERICH ALICE H
# 21    1594246392 NA { } Queens      732805 ⋯ MYMUN DELI AND GROCERY CORP
# 22    1594246392 NA { } Queens      724999 ⋯ TMW GROUP INC
# 23    1594246392 NA { } Queens      733097 ⋯ WALGREEN EASTERN CO INC
# 24    1594246392 NA { } Queens      742842 ⋯ AAA PLUS DELI & GRILL INC
# 25    1594246392 NA { } Queens      635753 ⋯ MUNCAN FOOD CORP
# 26    1594246392 NA { } Queens      715118 ⋯ CANDY SHOP (USA) INC
# 27    1594246392 NA { } Queens      729757 ⋯ ULLIS OIL MILL LLC
# 28    1594246392 NA { } Queens      639988 ⋯ ZHONG MEI (USA) TRADING INC
# 29    1594246325 NA { } Westchester 715748 ⋯ ZNA ENTERPRISE INC
# 30    1594246325 NA { } Dutchess    722540 ⋯ NANCY CONVENIENCE INC
# ⋮     ⋮          ⋮  ⋮   ⋮           ⋮      ⋱ ⋮
# 28307 1594246392 NA { } Queens      638329 ⋯ FAR ROCKAWAY DRUGS INC
# 28308 1594246392 NA { } Queens      741204 ⋯ 82ND ST GRILL CORP
# 28309 1594246392 NA { } Queens      633094 ⋯ KIM MYUNG SUP
# 28310 1594246392 NA { } Kings       721935 ⋯ 835 NOSTRAND CORP
# 28311 1594246392 NA { } Kings       717225 ⋯ GREEN APPLE DELI CORP
# 28312 1594246392 NA { } Queens      721321 ⋯ RAINBOW CONVENIENT SHOP INC
# 28313 1594246392 NA { } New York    738183 ⋯ AMAZON RETAIL LLC
# 28314 1594246392 NA { } Queens      635965 ⋯ GUELMONT LUMENE
# 28315 1594246392 NA { } Queens      707207 ⋯ TENOCHTITLAN DELI CORP
# 28316 1594246392 NA { } New York    623650 ⋯ FIFTH AVENUE GOURMET DELI INC
# 28317 1594246392 NA { } New York    623468 ⋯ ORGANIC PARADISE HEALTH FOODS INC
# 28318 1594246392 NA { } New York    709645 ⋯ EL TEPEYAC BUTCHER SHOP INC
# 28319 1594246392 NA { } Kings       670834 ⋯ KOSHER CONVENIENCE INC
# 28320 1594246392 NA { } Queens      727582 ⋯ ADAM AT 97TH STREET INC
# 28321 1594246392 NA { } New York    732319 ⋯ FULTON MARKET ASSOCIATION INC
# 28322 1594246392 NA { } Kings       718598 ⋯ 68TH ST GOURMET DELI CORP
# 28323 1594246392 NA { } New York    717075 ⋯ MOES 1 GOURMET DELI CORP
# 28324 1594246392 NA { } Queens      721359 ⋯ 7 DAYS CONVENIENCE STORE INC
# 28325 1594246392 NA { } New York    628137 ⋯ WESTERLY HEALTH FOODS INC
# 28326 1594246392 NA { } New York    629485 ⋯ VILLAGE GOURMET GROCERY INC
# 28327 1594246392 NA { } Kings       723797 ⋯ EAT CHIC CHOCOLATES LLC
# 28328 1594246392 NA { } Kings       708818 ⋯ LA JOYA FOOD MARKET CORP
# 28329 1594246392 NA { } New York    742939 ⋯ COLUMBIA 1 MARKET INC
# 28330 1594246392 NA { } New York    723915 ⋯ 501 GROCERY CORP
# 28331 1594246392 NA { } Queens      733080 ⋯ WALGREEN EASTERN CO INC
# 28332 1594246392 NA { } Kings       612367 ⋯ ATLANTIC BEST DELICATESSEN INC
# 28333 1594246392 NA { } Richmond    741730 ⋯ EGGERS EVENTS LLC
# 28334 1594246392 NA { } Richmond    740160 ⋯ TONY Z CORP
# 28335 1594246392 NA { } New York    627200 ⋯ CHELSEA HYPER MARKET INC
# 28336 1594246392 NA { } Queens      638014 ⋯ RCR FOOD CORP
#       X14                     X15     X16                            X17 X18
# 1     STEWARTS SHOP 221       NA      PO BOX 6 COR W&N MAIN ST
# 2     CHURCH MOBIL MART       NA      EXIT 40 SPELLMAN RD
# 3     CUMBERLAND FARMS 1592   NA      RT 9&9J PO BOX 160
# 4     KISS MART 802           NA      RIDGE AT LANGER ST
# 5     MILK RUN THE            3498    RT 145
# 6     DOLLAR GENERAL #18074   6726    TRANSIT RD
# 7     TOPS 364                NA      RT 5 87 E STATE ST
# 8     STEWARTS SHOP 264       NA      RT 9W AT CARTER AVE MIDDLEHOPE
# 9     TOPS 568                NA      RT 28 COOPERSTOWN COMMONS
# 10    XTRA MART 1414          804     RT 50
# 11    HARVEST MOON MKT        1512    RT 9
# 12    NORTH CREEK ENTERPRISES 1275    ST ROUTE 990 V
# 13    ACCORD KWIK MART        4990    RT 209
# 14    CUMBERLAND FARMS 1574   NA      MILL HILL RD&ELWYN LN
# 15    APPLE BIN FARM MARKET   NA      RT 9W 810 BROADWAY
# 16    DOLLAR GENERAL #17103   1280    RT 32
# 17    SPICE BOX THE           NA      RT 14A WINDMILL
# 18    ROBT T COCHRAN&CO       NA      UNT 408-412 NYC TERMINAL MKT
# 19    WILKLOW ORCHARD         NA      COURT ST BKLYN BOROUGH HALL
# 20    KNOLL KREST FARM        NA      GREEN MARKET UNION SQUARE
# 21    MYMUN DELI AND GROCERY  163-02  HILLSIDE AVE
# 22    TMW GROUP               83-20   BROADWAY
# 23    WALGREENS #17681        45-02   43RD AVENUE
# 24    AAA PLUS DELI & GRILL   102-02  34TH AVE
# 25    MUNCAN FOODS            43-09   BROADWAY
# 26    CANDY SHOP (USA)        37-14   MAIN ST
# 27    ULLIS OIL MILL LLC      36-46   37TH ST
# 28    ZHONG MEI (USA) TRADING 41-38   MAIN ST
# 29    FOOD LAB                1       PIER POINTE ST
# 30    NANCY CONVENIENCE INC   145     FISHKILL AVE
# ⋮     ⋮                       ⋮       ⋮                              ⋮   ⋮
# 28307 OCEAN PARK DRUGS        17-27   SEAGIRT BLVD
# 28308 82ND ST GRILL           82-02   ROOSEVELT AVE
# 28309 7-ELEVEN FD STR 32121B  208-22  CROSS ISLAND PKWY
# 28310 TONY'S MARKET           835     NOSTRAND AVENUE
# 28311 GREEN APPLE DELI        2321    MERMAID AVE
# 28312 RAINBOW CONVENIENT SHOP 86-24   ROOSEVELT AVE
# 28313 AMAZON GO               200     VESEY STREET
# 28314 GILS GROCERY STORE      87-36   148TH ST
# 28315 TENOCHTITLAN DELI       103-14  ASTORIA BLVD
# 28316 FIFTH AVENUE GRMT DELI  2289    5TH AVE
# 28317 ORGANIC PARADISE HEALTH 4532    BROADWAY
# 28318 EL TEPEYAC BUTCHER SHOP 1629    LEXINGTON AVE
# 28319 KOSHER CONVENIENCE      1304    AVENUE M
# 28320 ADAM AT 97TH STREET     9704    ROCKAWAY BLVD
# 28321 FULTON STALL MARKET     91      SOUTH STREET
# 28322 68TH ST GOURMET DELI    6803    3RD AVENUE
# 28323 MOES 1 GOURMET DELI     2738    FREDERICK DOUGLASS BLVD
# 28324 7 DAYS CONVENIENCE STOR 89-55   METROPOLITAN AVE
# 28325 WESTERLY HEALTH FOODS   911-913 8TH AVE
# 28326 VILLAGE MAGAZINE CIGAR  102     2ND AVE
# 28327 EAT CHIC CHOCOLATES     630     FLUSHING AVE FL 8
# 28328 ASSOCIATED              103     HEGEMAN AVE
# 28329 COLUMBIA 1 MARKET       20      OLD BROADWAY
# 28330 501 GROCERY             501     W 133RD ST
# 28331 WALGREENS #19694        110-88  QUEENS BOULEVARD
# 28332 ATLANTIC BEST DELI      2053    ATLANTIC AVE
# 28333 CHOCOLATE & BALLOONS    1398    FOREST AVE
# 28334 TERRYS TOWNE DELI       125     OLYMPIA BLVD
# 28335 CHELSEA HYPER MARKET    366     W 23RD ST
# 28336 KEY FOOD #1462          108-27  QUEENS BLVD
#       X19              X20 X21   X22
# 1     NEW BERLIN       NY  13411 2200
# 2     PLATTSBURGH      NY  12901 1000
# 3     COLUMBIAVILLE    NY  12050 1700
# 4     WEST SENECA      NY  14224 2400
# 5     EAST DURHAM      NY  12423 2400
# 6     LOCKPORT         NY  14094 0
# 7     SHERRILL         NY  13461 0
# 8     NEWBURGH         NY  12550 3000
# 9     COOPERSTOWN      NY  13326 32600
# 10    BURNT HILLS      NY  12027 2200
# 11    CLIFTON PARK     NY  12065 1800
# 12    GILBOA           NY  12076 3200
# 13    ACCORD           NY  12404 4000
# 14    WOODSTOCK        NY  12498 1250
# 15    ULSTER PARK      NY  12487 4000
# 16    WALLKILL         NY  12589 9000
# 17    PENN YAN         NY  14527 100
# 18    BRONX            NY  10474 0
# 19    BROOKLYN         NY  11201 200
# 20    NEW YORK         NY  10003 50
# 21    JAMAICA          NY  11432 0
# 22    ELMHURST         NY  11373 0
# 23    SUNNYSIDE        NY  11104 0
# 24    CORONA           NY  11368 2000
# 25    GRAND STATION    NY  11103 1800
# 26    FLUSHING         NY  11354 400
# 27    LONG ISLAND CITY NY  11101 0
# 28    FLUSHING         NY  11355 900
# 29    YONKERS          NY  10701 0
# 30    BEACON           NY  12508 1000
# ⋮     ⋮                ⋮   ⋮     ⋮
# 28307 FAR ROCKAWAY     NY  11691 800
# 28308 JACKSON HEIGHTS  NY  11372 500
# 28309 BAY TERRACE      NY  11360 1500
# 28310 BROOKLYN         NY  11225 2000
# 28311 BROOKLYN         NY  11224 1000
# 28312 JACKSON HEIGHTS  NY  11372 2000
# 28313 NEW YORK         NY  10281 0
# 28314 JAMAICA          NY  11435 200
# 28315 EAST ELMHURST    NY  11369 600
# 28316 NEW YORK         NY  10037 1500
# 28317 NEW YORK         NY  10040 800
# 28318 NEW YORK         NY  10029 1200
# 28319 BROOKLYN         NY  11230 2000
# 28320 OZONE PARK       NY  11417 1000
# 28321 NEW YORK         NY  10038 0
# 28322 BROOKLYN         NY  11220 1200
# 28323 NEW YORK         NY  10039 0
# 28324 REGO PARK        NY  11374 0
# 28325 NEW YORK         NY  10019 5000
# 28326 NEW YORK         NY  10003 900
# 28327 BROOKLYN         NY  11206 400
# 28328 BROOKLYN         NY  11212 5000
# 28329 NEW YORK         NY  10027 0
# 28330 NEW YORK         NY  10027 600
# 28331 FOREST HILLS     NY  11375 5000
# 28332 BROOKLYN         NY  11233 1500
# 28333 STATEN ISLAND    NY  10302 500
# 28334 STATEN ISLAND    NY  10305 2000
# 28335 NEW YORK         NY  10011 2900
# 28336 FOREST HILLS     NY  11375 15000

# %%
foodMarkets[[1]][[23]]
# Out:
# NULL

# %%
grabGeoInfo<-function(val){

    l<- length(foodMarkets[[1]][[val]])
    tmp<-lapply(1:l, function(y) 

      sapply(foodMarkets, function(x){

        if(!is.null(x[[val]][[y]])){
          return(x[[val]][[y]])
        }else{
          return(NA)
        }

        })     
      )
}

# %%
# add the names
columns<-foodMarketsRaw[['meta']][['view']][['columns']]

# %%
columns
# Out:
# [[1]]
# [[1]]$id
# [1] -1
#
# [[1]]$name
# [1] "sid"
#
# [[1]]$dataTypeName
# [1] "meta_data"
#
# [[1]]$fieldName
# [1] ":sid"
#
# [[1]]$position
# [1] 0
#
# [[1]]$renderTypeName
# [1] "meta_data"
#
# [[1]]$format
# named list()
#
# [[1]]$flags
# [1] "hidden"
#
#
# [[2]]
# [[2]]$id
# [1] -1
#
# [[2]]$name
# [1] "id"
#
# [[2]]$dataTypeName
# [1] "meta_data"
#
# [[2]]$fieldName
# [1] ":id"
#
# [[2]]$position
# [1] 0
#
# [[2]]$renderTypeName
# [1] "meta_data"
#
# [[2]]$format
# named list()
#
# [[2]]$flags
# [1] "hidden"
#
#
# [[3]]
# [[3]]$id
# [1] -1
#
# [[3]]$name
# [1] "position"
#
# [[3]]$dataTypeName
# [1] "meta_data"
#
# [[3]]$fieldName
# [1] ":position"
#
# [[3]]$position
# [1] 0
#
# [[3]]$renderTypeName
# [1] "meta_data"
#
# [[3]]$format
# named list()
#
# [[3]]$flags
# [1] "hidden"
#
#
# [[4]]
# [[4]]$id
# [1] -1
#
# [[4]]$name
# [1] "created_at"
#
# [[4]]$dataTypeName
# [1] "meta_data"
#
# [[4]]$fieldName
# [1] ":created_at"
#
# [[4]]$position
# [1] 0
#
# [[4]]$renderTypeName
# [1] "meta_data"
#
# [[4]]$format
# named list()
#
# [[4]]$flags
# [1] "hidden"
#
#
# [[5]]
# [[5]]$id
# [1] -1
#
# [[5]]$name
# [1] "created_meta"
#
# [[5]]$dataTypeName
# [1] "meta_data"
#
# [[5]]$fieldName
# [1] ":created_meta"
#
# [[5]]$position
# [1] 0
#
# [[5]]$renderTypeName
# [1] "meta_data"
#
# [[5]]$format
# named list()
#
# [[5]]$flags
# [1] "hidden"
#
#
# [[6]]
# [[6]]$id
# [1] -1
#
# [[6]]$name
# [1] "updated_at"
#
# [[6]]$dataTypeName
# [1] "meta_data"
#
# [[6]]$fieldName
# [1] ":updated_at"
#
# [[6]]$position
# [1] 0
#
# [[6]]$renderTypeName
# [1] "meta_data"
#
# [[6]]$format
# named list()
#
# [[6]]$flags
# [1] "hidden"
#
#
# [[7]]
# [[7]]$id
# [1] -1
#
# [[7]]$name
# [1] "updated_meta"
#
# [[7]]$dataTypeName
# [1] "meta_data"
#
# [[7]]$fieldName
# [1] ":updated_meta"
#
# [[7]]$position
# [1] 0
#
# [[7]]$renderTypeName
# [1] "meta_data"
#
# [[7]]$format
# named list()
#
# [[7]]$flags
# [1] "hidden"
#
#
# [[8]]
# [[8]]$id
# [1] -1
#
# [[8]]$name
# [1] "meta"
#
# [[8]]$dataTypeName
# [1] "meta_data"
#
# [[8]]$fieldName
# [1] ":meta"
#
# [[8]]$position
# [1] 0
#
# [[8]]$renderTypeName
# [1] "meta_data"
#
# [[8]]$format
# named list()
#
# [[8]]$flags
# [1] "hidden"
#
#
# [[9]]
# [[9]]$id
# [1] 479878414
#
# [[9]]$name
# [1] "County"
#
# [[9]]$dataTypeName
# [1] "text"
#
# [[9]]$description
# [1] "The county in which the licensed entity is physically located"
#
# [[9]]$fieldName
# [1] "county"
#
# [[9]]$position
# [1] 1
#
# [[9]]$renderTypeName
# [1] "text"
#
# [[9]]$tableColumnId
# [1] 8179659
#
# [[9]]$width
# [1] 137
#
# [[9]]$cachedContents
# [[9]]$cachedContents$non_null
# [1] "28336"
#
# [[9]]$cachedContents$largest
# [1] "Yates"
#
# [[9]]$cachedContents$null
# [1] "0"
#
# [[9]]$cachedContents$top
# [[9]]$cachedContents$top[[1]]
#    item   count
# "Kings"  "4910"
#
# [[9]]$cachedContents$top[[2]]
#     item    count
# "Queens"   "3026"
#
# [[9]]$cachedContents$top[[3]]
#       item      count
# "New York"     "2645"
#
# [[9]]$cachedContents$top[[4]]
#    item   count
# "Bronx"  "2511"
#
# [[9]]$cachedContents$top[[5]]
#      item     count
# "Suffolk"    "1885"
#
# [[9]]$cachedContents$top[[6]]
#     item    count
# "Nassau"   "1448"
#
# [[9]]$cachedContents$top[[7]]
#   item  count
# "Erie" "1249"
#
# [[9]]$cachedContents$top[[8]]
#          item         count
# "Westchester"        "1155"
#
# [[9]]$cachedContents$top[[9]]
#     item    count
# "Monroe"    "847"
#
# [[9]]$cachedContents$top[[10]]
#       item      count
# "Onondaga"      "625"
#
# [[9]]$cachedContents$top[[11]]
#       item      count
# "Richmond"      "572"
#
# [[9]]$cachedContents$top[[12]]
#     item    count
# "Orange"    "492"
#
# [[9]]$cachedContents$top[[13]]
#     item    count
# "Albany"    "457"
#
# [[9]]$cachedContents$top[[14]]
#       item      count
# "Dutchess"      "401"
#
# [[9]]$cachedContents$top[[15]]
#     item    count
# "Oneida"    "343"
#
# [[9]]$cachedContents$top[[16]]
#       item      count
# "Rockland"      "335"
#
# [[9]]$cachedContents$top[[17]]
#     item    count
# "Ulster"    "320"
#
# [[9]]$cachedContents$top[[18]]
#     item    count
# "Broome"    "270"
#
# [[9]]$cachedContents$top[[19]]
#       item      count
# "Saratoga"      "269"
#
# [[9]]$cachedContents$top[[20]]
#      item     count
# "Niagara"     "266"
#
#
# [[9]]$cachedContents$smallest
# [1] "Albany"
#
# [[9]]$cachedContents$cardinality
# [1] "62"
#
#
# [[9]]$format
#    align
# "center"
#
#
# [[10]]
# [[10]]$id
# [1] 479878415
#
# [[10]]$name
# [1] "License Number"
#
# [[10]]$dataTypeName
# [1] "text"
#
# [[10]]$description
# [1] "The licensed entity’s license number for this location"
#
# [[10]]$fieldName
# [1] "license_number"
#
# [[10]]$position
# [1] 2
#
# [[10]]$renderTypeName
# [1] "text"
#
# [[10]]$tableColumnId
# [1] 8179648
#
# [[10]]$width
# [1] 183
#
# [[10]]$cachedContents
# [[10]]$cachedContents$non_null
# [1] "28336"
#
# [[10]]$cachedContents$largest
# [1] "743585"
#
# [[10]]$cachedContents$null
# [1] "0"
#
# [[10]]$cachedContents$top
# [[10]]$cachedContents$top[[1]]
#     item    count
# "010056"      "1"
#
# [[10]]$cachedContents$top[[2]]
#     item    count
# "010066"      "1"
#
# [[10]]$cachedContents$top[[3]]
#     item    count
# "010070"      "1"
#
# [[10]]$cachedContents$top[[4]]
#     item    count
# "010086"      "1"
#
# [[10]]$cachedContents$top[[5]]
#     item    count
# "010090"      "1"
#
# [[10]]$cachedContents$top[[6]]
#     item    count
# "010103"      "1"
#
# [[10]]$cachedContents$top[[7]]
#     item    count
# "010115"      "1"
#
# [[10]]$cachedContents$top[[8]]
#     item    count
# "010134"      "1"
#
# [[10]]$cachedContents$top[[9]]
#     item    count
# "010135"      "1"
#
# [[10]]$cachedContents$top[[10]]
#     item    count
# "010166"      "1"
#
# [[10]]$cachedContents$top[[11]]
#     item    count
# "010169"      "1"
#
# [[10]]$cachedContents$top[[12]]
#     item    count
# "010172"      "1"
#
# [[10]]$cachedContents$top[[13]]
#     item    count
# "010179"      "1"
#
# [[10]]$cachedContents$top[[14]]
#     item    count
# "010197"      "1"
#
# [[10]]$cachedContents$top[[15]]
#     item    count
# "010206"      "1"
#
# [[10]]$cachedContents$top[[16]]
#     item    count
# "010221"      "1"
#
# [[10]]$cachedContents$top[[17]]
#     item    count
# "010222"      "1"
#
# [[10]]$cachedContents$top[[18]]
#     item    count
# "010227"      "1"
#
# [[10]]$cachedContents$top[[19]]
#     item    count
# "010230"      "1"
#
# [[10]]$cachedContents$top[[20]]
#     item    count
# "010231"      "1"
#
#
# [[10]]$cachedContents$smallest
# [1] "010008"
#
# [[10]]$cachedContents$cardinality
# [1] "28336"
#
#
# [[10]]$format
#    align
# "center"
#
#
# [[11]]
# [[11]]$id
# [1] 479878416
#
# [[11]]$name
# [1] "Operation Type"
#
# [[11]]$dataTypeName
# [1] "text"
#
# [[11]]$description
# [1] "The type of operation the licensed entity conducts"
#
# [[11]]$fieldName
# [1] "operation_type"
#
# [[11]]$position
# [1] 3
#
# [[11]]$renderTypeName
# [1] "text"
#
# [[11]]$tableColumnId
# [1] 8179649
#
# [[11]]$width
# [1] 176
#
# [[11]]$cachedContents
# [[11]]$cachedContents$non_null
# [1] "28336"
#
# [[11]]$cachedContents$largest
# [1] "Store"
#
# [[11]]$cachedContents$null
# [1] "0"
#
# [[11]]$cachedContents$top
# [[11]]$cachedContents$top[[1]]
#    item   count
# "Store" "28336"
#
#
# [[11]]$cachedContents$smallest
# [1] "Store"
#
# [[11]]$cachedContents$cardinality
# [1] "1"
#
#
# [[11]]$format
#    align
# "center"
#
#
# [[12]]
# [[12]]$id
# [1] 479878417
#
# [[12]]$name
# [1] "Establishment Type"
#
# [[12]]$dataTypeName
# [1] "text"
#
# [[12]]$description
# [1] "The establishment type for the licensed entity at this location; see document in ‘About’ section, or go to https://data.ny.gov/api/views/9a8c-vfzj/files/UBDP3oW2f-K767I4f51EJaIUO8eNGPrAQQj8tSvBhbo?download=true&filename=NYSDAM_RetailFoodStoresEstablishmentTypeCodes.pdf"
#
# [[12]]$fieldName
# [1] "estab_type"
#
# [[12]]$position
# [1] 4
#
# [[12]]$renderTypeName
# [1] "text"
#
# [[12]]$tableColumnId
# [1] 21635505
#
# [[12]]$width
# [1] 196
#
# [[12]]$cachedContents
# [[12]]$cachedContents$non_null
# [1] "28336"
#
# [[12]]$cachedContents$largest
# [1] "JKDA  "
#
# [[12]]$cachedContents$null
# [1] "0"
#
# [[12]]$cachedContents$top
# [[12]]$cachedContents$top[[1]]
#     item    count
# "JAC   "  "19357"
#
# [[12]]$cachedContents$top[[2]]
#     item    count
# "A     "   "6681"
#
# [[12]]$cachedContents$top[[3]]
#     item    count
# "JABC  "   "1289"
#
# [[12]]$cachedContents$top[[4]]
#     item    count
# "JACH  "    "150"
#
# [[12]]$cachedContents$top[[5]]
#     item    count
# "JACD  "    "126"
#
# [[12]]$cachedContents$top[[6]]
#     item    count
# "JABCH "    "105"
#
# [[12]]$cachedContents$top[[7]]
#     item    count
# "JACK  "     "89"
#
# [[12]]$cachedContents$top[[8]]
#     item    count
# "JACDK "     "66"
#
# [[12]]$cachedContents$top[[9]]
#     item    count
# "JAD   "     "48"
#
# [[12]]$cachedContents$top[[10]]
#     item    count
# "JABH  "     "41"
#
# [[12]]$cachedContents$top[[11]]
#     item    count
# "JABCK "     "32"
#
# [[12]]$cachedContents$top[[12]]
#     item    count
# "JAB   "     "32"
#
# [[12]]$cachedContents$top[[13]]
#     item    count
# "JADK  "     "31"
#
# [[12]]$cachedContents$top[[14]]
#     item    count
# "JACW  "     "30"
#
# [[12]]$cachedContents$top[[15]]
#     item    count
# "JABCHK"     "23"
#
# [[12]]$cachedContents$top[[16]]
#     item    count
# "JACHK "     "22"
#
# [[12]]$cachedContents$top[[17]]
#     item    count
# "JABHK "     "20"
#
# [[12]]$cachedContents$top[[18]]
#     item    count
# "JACDHK"     "16"
#
# [[12]]$cachedContents$top[[19]]
#     item    count
# "JAW   "     "14"
#
# [[12]]$cachedContents$top[[20]]
#     item    count
# "JACE  "     "13"
#
#
# [[12]]$cachedContents$smallest
# [1] "A     "
#
# [[12]]$cachedContents$cardinality
# [1] "83"
#
#
# [[12]]$format
#    align
# "center"
#
#
# [[13]]
# [[13]]$id
# [1] 479878418
#
# [[13]]$name
# [1] "Entity Name"
#
# [[13]]$dataTypeName
# [1] "text"
#
# [[13]]$description
# [1] "The name of the licensed entity"
#
# [[13]]$fieldName
# [1] "entity_name"
#
# [[13]]$position
# [1] 5
#
# [[13]]$renderTypeName
# [1] "text"
#
# [[13]]$tableColumnId
# [1] 8179650
#
# [[13]]$width
# [1] 306
#
# [[13]]$cachedContents
# [[13]]$cachedContents$non_null
# [1] "28336"
#
# [[13]]$cachedContents$largest
# [1] "Z&Z TWO BROTHERS INC             "
#
# [[13]]$cachedContents$null
# [1] "0"
#
# [[13]]$cachedContents$top
# [[13]]$cachedContents$top[[1]]
#                                item                               count
# "CVS ALBANY LLC                   "                               "490"
#
# [[13]]$cachedContents$top[[2]]
#                                item                               count
# "WALGREEN EASTERN CO INC          "                               "429"
#
# [[13]]$cachedContents$top[[3]]
#                                item                               count
# "DOLGENCORP OF NEW YORK INC       "                               "418"
#
# [[13]]$cachedContents$top[[4]]
#                                item                               count
# "STEWARTS SHOPS CORP              "                               "329"
#
# [[13]]$cachedContents$top[[5]]
#                                item                               count
# "DOLLAR TREE STORES INC           "                               "328"
#
# [[13]]$cachedContents$top[[6]]
#                                item                               count
# "SPEEDWAY LLC                     "                               "284"
#
# [[13]]$cachedContents$top[[7]]
#                                item                               count
# "FAMILY DOLLAR STORES OF NY INC   "                               "256"
#
# [[13]]$cachedContents$top[[8]]
#                                item                               count
# "RITE AID OF NEW YORK INC         "                               "172"
#
# [[13]]$cachedContents$top[[9]]
#                                item                               count
# "7-ELEVEN INC                     "                               "146"
#
# [[13]]$cachedContents$top[[10]]
#                                item                               count
# "UNITED REFINING CO OF PA INC     "                               "129"
#
# [[13]]$cachedContents$top[[11]]
#                                item                               count
# "TOPS MARKETS LLC                 "                               "109"
#
# [[13]]$cachedContents$top[[12]]
#                                item                               count
# "ALDI INC                         "                               "105"
#
# [[13]]$cachedContents$top[[13]]
#                                item                               count
# "MIRABITO HOLDINGS INC            "                               "100"
#
# [[13]]$cachedContents$top[[14]]
#                                item                               count
# "WAL-MART STORES EAST LP          "                                "91"
#
# [[13]]$cachedContents$top[[15]]
#                                item                               count
# "CUMBERLAND FARMS INC             "                                "81"
#
# [[13]]$cachedContents$top[[16]]
#                                item                               count
# "PRICE CHOPPER OPERATING CO INC   "                                "80"
#
# [[13]]$cachedContents$top[[17]]
#                                item                               count
# "GENERAL NUTRITION CORP           "                                "77"
#
# [[13]]$cachedContents$top[[18]]
#                                item                               count
# "STOP&SHOP SUPERMARKET CO LLC THE "                                "77"
#
# [[13]]$cachedContents$top[[19]]
#                                item                               count
# "ECKERD CORP                      "                                "75"
#
# [[13]]$cachedContents$top[[20]]
#                                item                               count
# "REID STORES INC                  "                                "70"
#
#
# [[13]]$cachedContents$smallest
# [1] "0325 TUTA CORP                   "
#
# [[13]]$cachedContents$cardinality
# [1] "21798"
#
#
# [[13]]$format
#  align
# "left"
#
#
# [[14]]
# [[14]]$id
# [1] 479878419
#
# [[14]]$name
# [1] "DBA Name"
#
# [[14]]$dataTypeName
# [1] "text"
#
# [[14]]$description
# [1] "“Doing business as” (DBA) name for the licensed entity"
#
# [[14]]$fieldName
# [1] "dba_name"
#
# [[14]]$position
# [1] 6
#
# [[14]]$renderTypeName
# [1] "text"
#
# [[14]]$tableColumnId
# [1] 8179651
#
# [[14]]$width
# [1] 196
#
# [[14]]$cachedContents
# [[14]]$cachedContents$non_null
# [1] "28336"
#
# [[14]]$cachedContents$largest
# [1] "ZZ DELI GROCERY        "
#
# [[14]]$cachedContents$null
# [1] "0"
#
# [[14]]$cachedContents$top
# [[14]]$cachedContents$top[[1]]
#                      item                     count
# "EDIBLE ARRANGEMENTS    "                      "67"
#
# [[14]]$cachedContents$top[[2]]
#                      item                     count
# "C TOWN                 "                      "51"
#
# [[14]]$cachedContents$top[[3]]
#                      item                     count
# "KEY FOOD               "                      "45"
#
# [[14]]$cachedContents$top[[4]]
#                      item                     count
# "MOBIL MART             "                      "42"
#
# [[14]]$cachedContents$top[[5]]
#                      item                     count
# "HISSHO SUSHI@STOP&SHOP#"                      "36"
#
# [[14]]$cachedContents$top[[6]]
#                      item                     count
# "BP                     "                      "32"
#
# [[14]]$cachedContents$top[[7]]
#                      item                     count
# "CROSBYS                "                      "29"
#
# [[14]]$cachedContents$top[[8]]
#                      item                     count
# "FINE FARE              "                      "27"
#
# [[14]]$cachedContents$top[[9]]
#                      item                     count
# "BRAVO SUPERMARKET      "                      "25"
#
# [[14]]$cachedContents$top[[10]]
#                      item                     count
# "FINE FARE SUPERMARKET  "                      "24"
#
# [[14]]$cachedContents$top[[11]]
#                      item                     count
# "SUNOCO                 "                      "24"
#
# [[14]]$cachedContents$top[[12]]
#                      item                     count
# "FOOD UNIVERSE          "                      "20"
#
# [[14]]$cachedContents$top[[13]]
#                      item                     count
# "BIMBO BAKERIES USA     "                      "20"
#
# [[14]]$cachedContents$top[[14]]
#                      item                     count
# "AFC SUSHI @ PRICE CHOPP"                      "20"
#
# [[14]]$cachedContents$top[[15]]
#                      item                     count
# "IDEAL FOOD BASKET      "                      "19"
#
# [[14]]$cachedContents$top[[16]]
#                      item                     count
# "DOLLAR GENERAL STORE #1"                      "19"
#
# [[14]]$cachedContents$top[[17]]
#                      item                     count
# "BP SHOP                "                      "19"
#
# [[14]]$cachedContents$top[[18]]
#                      item                     count
# "CLIFFS LOCAL MARKET    "                      "19"
#
# [[14]]$cachedContents$top[[19]]
#                      item                     count
# "FOODTOWN               "                      "19"
#
# [[14]]$cachedContents$top[[20]]
#                      item                     count
# "WHOLE FOODS MARKET     "                      "18"
#
#
# [[14]]$cachedContents$smallest
# [1] "                       "
#
# [[14]]$cachedContents$cardinality
# [1] "25983"
#
#
# [[14]]$format
#  align
# "left"
#
#
# [[15]]
# [[15]]$id
# [1] 479878420
#
# [[15]]$name
# [1] "Street Number"
#
# [[15]]$dataTypeName
# [1] "text"
#
# [[15]]$description
# [1] "The street number for the physical address of the licensed entity; will be blank if no data is recorded"
#
# [[15]]$fieldName
# [1] "street_number"
#
# [[15]]$position
# [1] 7
#
# [[15]]$renderTypeName
# [1] "text"
#
# [[15]]$tableColumnId
# [1] 8179652
#
# [[15]]$width
# [1] 174
#
# [[15]]$cachedContents
# [[15]]$cachedContents$non_null
# [1] "28129"
#
# [[15]]$cachedContents$largest
# [1] "9A"
#
# [[15]]$cachedContents$null
# [1] "207"
#
# [[15]]$cachedContents$top
# [[15]]$cachedContents$top[[1]]
#  item count
#   "1" "171"
#
# [[15]]$cachedContents$top[[2]]
#  item count
#   "2" "117"
#
# [[15]]$cachedContents$top[[3]]
#  item count
# "100"  "96"
#
# [[15]]$cachedContents$top[[4]]
#  item count
#  "10"  "82"
#
# [[15]]$cachedContents$top[[5]]
#  item count
#  "50"  "79"
#
# [[15]]$cachedContents$top[[6]]
#  item count
#  "40"  "69"
#
# [[15]]$cachedContents$top[[7]]
#  item count
# "200"  "68"
#
# [[15]]$cachedContents$top[[8]]
#  item count
#  "15"  "67"
#
# [[15]]$cachedContents$top[[9]]
#  item count
#  "20"  "66"
#
# [[15]]$cachedContents$top[[10]]
#  item count
#   "4"  "59"
#
# [[15]]$cachedContents$top[[11]]
#  item count
#   "5"  "59"
#
# [[15]]$cachedContents$top[[12]]
#  item count
# "500"  "58"
#
# [[15]]$cachedContents$top[[13]]
#  item count
# "120"  "58"
#
# [[15]]$cachedContents$top[[14]]
#  item count
# "300"  "55"
#
# [[15]]$cachedContents$top[[15]]
#  item count
#   "7"  "54"
#
# [[15]]$cachedContents$top[[16]]
#  item count
# "101"  "53"
#
# [[15]]$cachedContents$top[[17]]
#  item count
#  "51"  "52"
#
# [[15]]$cachedContents$top[[18]]
#  item count
# "630"  "52"
#
# [[15]]$cachedContents$top[[19]]
#  item count
#   "9"  "52"
#
# [[15]]$cachedContents$top[[20]]
#  item count
# "111"  "51"
#
#
# [[15]]$cachedContents$smallest
# [1] "1"
#
# [[15]]$cachedContents$cardinality
# [1] "8379"
#
#
# [[15]]$format
#    align
# "center"
#
#
# [[16]]
# [[16]]$id
# [1] 479878421
#
# [[16]]$name
# [1] "Street Name"
#
# [[16]]$dataTypeName
# [1] "text"
#
# [[16]]$description
# [1] "The street name for the physical location of the licensed entity; the first address line recorded"
#
# [[16]]$fieldName
# [1] "street_name"
#
# [[16]]$position
# [1] 8
#
# [[16]]$renderTypeName
# [1] "text"
#
# [[16]]$tableColumnId
# [1] 8179653
#
# [[16]]$width
# [1] 232
#
# [[16]]$cachedContents
# [[16]]$cachedContents$non_null
# [1] "28336"
#
# [[16]]$cachedContents$largest
# [1] "ZEREGA AVENUE               "
#
# [[16]]$cachedContents$null
# [1] "0"
#
# [[16]]$cachedContents$top
# [[16]]$cachedContents$top[[1]]
#                           item                          count
# "BROADWAY                    "                          "251"
#
# [[16]]$cachedContents$top[[2]]
#                            item                           count
# "MAIN ST                      "                           "180"
#
# [[16]]$cachedContents$top[[3]]
#                            item                           count
# "BROADWAY                     "                           "152"
#
# [[16]]$cachedContents$top[[4]]
#                           item                          count
# "3RD AVE                     "                          "104"
#
# [[16]]$cachedContents$top[[5]]
#                         item                        count
# "JAMAICA AVE               "                         "94"
#
# [[16]]$cachedContents$top[[6]]
#                           item                          count
# "WHITE PLAINS RD             "                           "92"
#
# [[16]]$cachedContents$top[[7]]
#                           item                          count
# "CHURCH AVE                  "                           "90"
#
# [[16]]$cachedContents$top[[8]]
#                           item                          count
# "MAIN ST                     "                           "85"
#
# [[16]]$cachedContents$top[[9]]
#                           item                          count
# "5TH AVE                     "                           "85"
#
# [[16]]$cachedContents$top[[10]]
#                           item                          count
# "NOSTRAND AVE                "                           "83"
#
# [[16]]$cachedContents$top[[11]]
#                         item                        count
# "HILLSIDE AVE              "                         "78"
#
# [[16]]$cachedContents$top[[12]]
#                           item                          count
# "FULTON ST                   "                           "74"
#
# [[16]]$cachedContents$top[[13]]
#                             item                            count
# "MAIN ST                       "                             "65"
#
# [[16]]$cachedContents$top[[14]]
#                            item                           count
# "E MAIN ST                    "                            "64"
#
# [[16]]$cachedContents$top[[15]]
#                         item                        count
# "LIBERTY AVE               "                         "63"
#
# [[16]]$cachedContents$top[[16]]
#                          item                         count
# "BROADWAY                   "                          "62"
#
# [[16]]$cachedContents$top[[17]]
#                           item                          count
# "WESTCHESTER AVE             "                           "58"
#
# [[16]]$cachedContents$top[[18]]
#                           item                          count
# "FLATBUSH AVE                "                           "58"
#
# [[16]]$cachedContents$top[[19]]
#                            item                           count
# "W MAIN ST                    "                            "57"
#
# [[16]]$cachedContents$top[[20]]
#                           item                          count
# "18TH AVE                    "                           "56"
#
#
# [[16]]$cachedContents$smallest
# [1] "02 ATLANTIC AVE           "
#
# [[16]]$cachedContents$cardinality
# [1] "13142"
#
#
# [[16]]$format
#  align
# "left"
#
#
# [[17]]
# [[17]]$id
# [1] 479878422
#
# [[17]]$name
# [1] "Address Line 2"
#
# [[17]]$dataTypeName
# [1] "text"
#
# [[17]]$description
# [1] "The second address line recorded for the physical location of the licensed entity; blank if no data is recorded"
#
# [[17]]$fieldName
# [1] "address_line_2"
#
# [[17]]$position
# [1] 9
#
# [[17]]$renderTypeName
# [1] "text"
#
# [[17]]$tableColumnId
# [1] 8179654
#
# [[17]]$width
# [1] 188
#
# [[17]]$cachedContents
# [[17]]$cachedContents$non_null
# [1] "28336"
#
# [[17]]$cachedContents$largest
# [1] "             "
#
# [[17]]$cachedContents$null
# [1] "0"
#
# [[17]]$cachedContents$top
# [[17]]$cachedContents$top[[1]]
#            item           count
# "             "         "28336"
#
#
# [[17]]$cachedContents$smallest
# [1] "             "
#
# [[17]]$cachedContents$cardinality
# [1] "1"
#
#
# [[17]]$format
#  align
# "left"
#
#
# [[18]]
# [[18]]$id
# [1] 479878423
#
# [[18]]$name
# [1] "Address Line 3"
#
# [[18]]$dataTypeName
# [1] "text"
#
# [[18]]$description
# [1] "The third address line recorded for the physical location of the licensed entity; blank if no data is recorded"
#
# [[18]]$fieldName
# [1] "address_line_3"
#
# [[18]]$position
# [1] 10
#
# [[18]]$renderTypeName
# [1] "text"
#
# [[18]]$tableColumnId
# [1] 8179655
#
# [[18]]$width
# [1] 187
#
# [[18]]$cachedContents
# [[18]]$cachedContents$non_null
# [1] "28336"
#
# [[18]]$cachedContents$largest
# [1] "               "
#
# [[18]]$cachedContents$null
# [1] "0"
#
# [[18]]$cachedContents$top
# [[18]]$cachedContents$top[[1]]
#              item             count
# "               "           "28336"
#
#
# [[18]]$cachedContents$smallest
# [1] "               "
#
# [[18]]$cachedContents$cardinality
# [1] "1"
#
#
# [[18]]$format
#  align
# "left"
#
#
# [[19]]
# [[19]]$id
# [1] 479878424
#
# [[19]]$name
# [1] "City"
#
# [[19]]$dataTypeName
# [1] "text"
#
# [[19]]$description
# [1] "The name of the city in which the licensed entity is physically located"
#
# [[19]]$fieldName
# [1] "city"
#
# [[19]]$position
# [1] 11
#
# [[19]]$renderTypeName
# [1] "text"
#
# [[19]]$tableColumnId
# [1] 8179656
#
# [[19]]$width
# [1] 148
#
# [[19]]$cachedContents
# [[19]]$cachedContents$non_null
# [1] "28336"
#
# [[19]]$cachedContents$largest
# [1] "YOUNGSVILLE       "
#
# [[19]]$cachedContents$null
# [1] "0"
#
# [[19]]$cachedContents$top
# [[19]]$cachedContents$top[[1]]
#                 item                count
# "BROOKLYN          "               "4906"
#
# [[19]]$cachedContents$top[[2]]
#                 item                count
# "NEW YORK          "               "2638"
#
# [[19]]$cachedContents$top[[3]]
#                 item                count
# "BRONX             "               "2511"
#
# [[19]]$cachedContents$top[[4]]
#                 item                count
# "BUFFALO           "                "677"
#
# [[19]]$cachedContents$top[[5]]
#                 item                count
# "ROCHESTER         "                "668"
#
# [[19]]$cachedContents$top[[6]]
#                 item                count
# "STATEN ISLAND     "                "572"
#
# [[19]]$cachedContents$top[[7]]
#                 item                count
# "SYRACUSE          "                "365"
#
# [[19]]$cachedContents$top[[8]]
#                 item                count
# "JAMAICA           "                "339"
#
# [[19]]$cachedContents$top[[9]]
#                 item                count
# "YONKERS           "                "285"
#
# [[19]]$cachedContents$top[[10]]
#                 item                count
# "ALBANY            "                "285"
#
# [[19]]$cachedContents$top[[11]]
#                 item                count
# "ASTORIA           "                "240"
#
# [[19]]$cachedContents$top[[12]]
#                 item                count
# "FLUSHING          "                "213"
#
# [[19]]$cachedContents$top[[13]]
#                 item                count
# "CORONA            "                "191"
#
# [[19]]$cachedContents$top[[14]]
#                 item                count
# "RIDGEWOOD         "                "191"
#
# [[19]]$cachedContents$top[[15]]
#                 item                count
# "SCHENECTADY       "                "173"
#
# [[19]]$cachedContents$top[[16]]
#                 item                count
# "LONG ISLAND CITY  "                "147"
#
# [[19]]$cachedContents$top[[17]]
#                 item                count
# "POUGHKEEPSIE      "                "142"
#
# [[19]]$cachedContents$top[[18]]
#                 item                count
# "JACKSON HEIGHTS   "                "140"
#
# [[19]]$cachedContents$top[[19]]
#                 item                count
# "UTICA             "                "126"
#
# [[19]]$cachedContents$top[[20]]
#                 item                count
# "WOODSIDE          "                "123"
#
#
# [[19]]$cachedContents$smallest
# [1] "                  "
#
# [[19]]$cachedContents$cardinality
# [1] "1434"
#
#
# [[19]]$format
#  align
# "left"
#
#
# [[20]]
# [[20]]$id
# [1] 479878425
#
# [[20]]$name
# [1] "State"
#
# [[20]]$dataTypeName
# [1] "text"
#
# [[20]]$description
# [1] "The two character state code for the physical location of the licensed entity"
#
# [[20]]$fieldName
# [1] "state"
#
# [[20]]$position
# [1] 12
#
# [[20]]$renderTypeName
# [1] "text"
#
# [[20]]$tableColumnId
# [1] 8179657
#
# [[20]]$width
# [1] 123
#
# [[20]]$cachedContents
# [[20]]$cachedContents$non_null
# [1] "28336"
#
# [[20]]$cachedContents$largest
# [1] "NY"
#
# [[20]]$cachedContents$null
# [1] "0"
#
# [[20]]$cachedContents$top
# [[20]]$cachedContents$top[[1]]
#    item   count
#    "NY" "28336"
#
#
# [[20]]$cachedContents$smallest
# [1] "NY"
#
# [[20]]$cachedContents$cardinality
# [1] "1"
#
#
# [[20]]$format
#    align
# "center"
#
#
# [[21]]
# [[21]]$id
# [1] 479878426
#
# [[21]]$name
# [1] "Zip Code"
#
# [[21]]$dataTypeName
# [1] "text"
#
# [[21]]$description
# [1] "The United States Postal Service (USPS) ZIP code for the physical location of the licensed entity"
#
# [[21]]$fieldName
# [1] "zip_code"
#
# [[21]]$position
# [1] 13
#
# [[21]]$renderTypeName
# [1] "text"
#
# [[21]]$tableColumnId
# [1] 8179658
#
# [[21]]$width
# [1] 152
#
# [[21]]$cachedContents
# [[21]]$cachedContents$non_null
# [1] "28336"
#
# [[21]]$cachedContents$largest
# [1] "14905"
#
# [[21]]$cachedContents$null
# [1] "0"
#
# [[21]]$cachedContents$top
# [[21]]$cachedContents$top[[1]]
#    item   count
# "11220"   "227"
#
# [[21]]$cachedContents$top[[2]]
#    item   count
# "11226"   "225"
#
# [[21]]$cachedContents$top[[3]]
#    item   count
# "11385"   "204"
#
# [[21]]$cachedContents$top[[4]]
#    item   count
# "11212"   "197"
#
# [[21]]$cachedContents$top[[5]]
#    item   count
# "11207"   "195"
#
# [[21]]$cachedContents$top[[6]]
#    item   count
# "11208"   "194"
#
# [[21]]$cachedContents$top[[7]]
#    item   count
# "10467"   "194"
#
# [[21]]$cachedContents$top[[8]]
#    item   count
# "10002"   "193"
#
# [[21]]$cachedContents$top[[9]]
#    item   count
# "11211"   "193"
#
# [[21]]$cachedContents$top[[10]]
#    item   count
# "11368"   "192"
#
# [[21]]$cachedContents$top[[11]]
#    item   count
# "11221"   "181"
#
# [[21]]$cachedContents$top[[12]]
#    item   count
# "10458"   "179"
#
# [[21]]$cachedContents$top[[13]]
#    item   count
# "10029"   "176"
#
# [[21]]$cachedContents$top[[14]]
#    item   count
# "11206"   "174"
#
# [[21]]$cachedContents$top[[15]]
#    item   count
# "11223"   "171"
#
# [[21]]$cachedContents$top[[16]]
#    item   count
# "11219"   "166"
#
# [[21]]$cachedContents$top[[17]]
#    item   count
# "10456"   "163"
#
# [[21]]$cachedContents$top[[18]]
#    item   count
# "11214"   "158"
#
# [[21]]$cachedContents$top[[19]]
#    item   count
# "10452"   "158"
#
# [[21]]$cachedContents$top[[20]]
#    item   count
# "11235"   "155"
#
#
# [[21]]$cachedContents$smallest
# [1] "06390"
#
# [[21]]$cachedContents$cardinality
# [1] "1538"
#
#
# [[21]]$format
#    align
# "center"
#
#
# [[22]]
# [[22]]$id
# [1] 479878427
#
# [[22]]$name
# [1] "Square Footage"
#
# [[22]]$dataTypeName
# [1] "number"
#
# [[22]]$description
# [1] "The square footage of the entire physical location of the licensed entity"
#
# [[22]]$fieldName
# [1] "square_footage"
#
# [[22]]$position
# [1] 14
#
# [[22]]$renderTypeName
# [1] "number"
#
# [[22]]$tableColumnId
# [1] 21635506
#
# [[22]]$width
# [1] 184
#
# [[22]]$cachedContents
# [[22]]$cachedContents$non_null
# [1] "28336"
#
# [[22]]$cachedContents$largest
# [1] "850000"
#
# [[22]]$cachedContents$null
# [1] "0"
#
# [[22]]$cachedContents$top
# [[22]]$cachedContents$top[[1]]
#   item  count
#    "0" "4870"
#
# [[22]]$cachedContents$top[[2]]
#   item  count
# "1000" "2584"
#
# [[22]]$cachedContents$top[[3]]
#   item  count
# "1500" "2018"
#
# [[22]]$cachedContents$top[[4]]
#   item  count
# "2000" "1906"
#
# [[22]]$cachedContents$top[[5]]
#   item  count
# "1200" "1690"
#
# [[22]]$cachedContents$top[[6]]
#   item  count
# "3000"  "951"
#
# [[22]]$cachedContents$top[[7]]
#  item count
# "800" "927"
#
# [[22]]$cachedContents$top[[8]]
#   item  count
# "2500"  "791"
#
# [[22]]$cachedContents$top[[9]]
#   item  count
# "1800"  "723"
#
# [[22]]$cachedContents$top[[10]]
#   item  count
# "5000"  "584"
#
# [[22]]$cachedContents$top[[11]]
#  item count
# "500" "576"
#
# [[22]]$cachedContents$top[[12]]
#   item  count
# "4000"  "504"
#
# [[22]]$cachedContents$top[[13]]
#    item   count
# "10000"   "502"
#
# [[22]]$cachedContents$top[[14]]
#  item count
# "900" "427"
#
# [[22]]$cachedContents$top[[15]]
#  item count
# "600" "402"
#
# [[22]]$cachedContents$top[[16]]
#   item  count
# "1600"  "379"
#
# [[22]]$cachedContents$top[[17]]
#   item  count
# "8000"  "327"
#
# [[22]]$cachedContents$top[[18]]
#   item  count
# "1100"  "290"
#
# [[22]]$cachedContents$top[[19]]
#  item count
# "700" "287"
#
# [[22]]$cachedContents$top[[20]]
#   item  count
# "1400"  "283"
#
#
# [[22]]$cachedContents$smallest
# [1] "0"
#
# [[22]]$cachedContents$cardinality
# [1] "869"
#
#
# [[22]]$format
# precisionStyle          align
#     "standard"        "right"
#
#
# [[23]]
# [[23]]$id
# [1] 479878428
#
# [[23]]$name
# [1] "Location"
#
# [[23]]$dataTypeName
# [1] "location"
#
# [[23]]$description
# [1] "Open Data/Socrata-generated geocoding information"
#
# [[23]]$fieldName
# [1] "location"
#
# [[23]]$position
# [1] 15
#
# [[23]]$renderTypeName
# [1] "location"
#
# [[23]]$tableColumnId
# [1] 8179660
#
# [[23]]$width
# [1] 196
#
# [[23]]$format
#  align
# "left"
#
# [[23]]$subColumnTypes
# [1] "human_address"   "latitude"        "longitude"       "machine_address"
# [5] "needs_recoding"
#
#
# [[24]]
# [[24]]$id
# [1] 479878433
#
# [[24]]$name
# [1] "Counties"
#
# [[24]]$dataTypeName
# [1] "number"
#
# [[24]]$fieldName
# [1] ":@computed_region_kjdx_g34t"
#
# [[24]]$position
# [1] 20
#
# [[24]]$renderTypeName
# [1] "number"
#
# [[24]]$tableColumnId
# [1] 32135079
#
# [[24]]$computationStrategy
# [[24]]$computationStrategy$source_columns
# [1] "location"
#
# [[24]]$computationStrategy$type
# [1] "georegion_match_on_point"
#
# [[24]]$computationStrategy$parameters
#        region   primary_key
#  "_kjdx-g34t" "_feature_id"
#
#
# [[24]]$format
# named list()
#
#
# [[25]]
# [[25]]$id
# [1] 479878434
#
# [[25]]$name
# [1] "New York Zip Codes"
#
# [[25]]$dataTypeName
# [1] "number"
#
# [[25]]$fieldName
# [1] ":@computed_region_wbg7_3whc"
#
# [[25]]$position
# [1] 21
#
# [[25]]$renderTypeName
# [1] "number"
#
# [[25]]$tableColumnId
# [1] 32135080
#
# [[25]]$computationStrategy
# [[25]]$computationStrategy$source_columns
# [1] "location"
#
# [[25]]$computationStrategy$type
# [1] "georegion_match_on_point"
#
# [[25]]$computationStrategy$parameters
#        region   primary_key
#  "_wbg7-3whc" "_feature_id"
#
#
# [[25]]$format
# named list()

# %%
# extract names for geo and non-geo
getNames<-function(x){
  if(is.null(columns[[x]]$subColumnTypes)){
    return(columns[[x]]$name)
  }else{
    return(columns[[x]]$subColumnTypes)
  }
}

fmNames<-unlist(sapply(1:length(columns), getNames))

# %%
names(fmDataDF)<-fmNames
head(fmDataDF)
# Out:
# Error in names(fmDataDF) <- fmNames: 'names' attribute [29] must be the same length as the vector [22]
# Traceback:

# %%
# long lat
fmDataDF$latitude<-as.numeric(fmDataDF$latitude)
fmDataDF$longitude<-as.numeric(fmDataDF$longitude)
# Out:
# Error in `$<-.data.frame`(`*tmp*`, latitude, value = numeric(0)): replacement has 0 rows, data has 28336
# Traceback:
#
# 1. `$<-`(`*tmp*`, latitude, value = numeric(0))
# 2. `$<-.data.frame`(`*tmp*`, latitude, value = numeric(0))
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
 install.packages("rgdal")
# Out:
# The downloaded binary packages are in
# 	/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T//RtmpmHitwx/downloaded_packages

# %%
# visualization

library(rgdal)
library(ggplot2)
state<-readOGR("X:/administrative/social_media/blogposts/json_from_R", layer="nys")
## OGR data source with driver: ESRI Shapefile 
## Source: "X:/administrative/social_media/blogposts/json_from_R", layer: "nys"
## with 1 features and 53 fields
## Feature type: wkbMultiPolygon with 2 dimensions
# Out:
# Loading required package: sp
#
# rgdal: version: 1.5-16, (SVN revision 1050)
# Geospatial Data Abstraction Library extensions to R successfully loaded
# Loaded GDAL runtime: GDAL 2.4.2, released 2019/06/28
# Path to GDAL shared files: /Library/Frameworks/R.framework/Versions/3.6/Resources/library/rgdal/gdal
# GDAL binary built with GEOS: FALSE
# Loaded PROJ runtime: Rel. 5.2.0, September 15th, 2018, [PJ_VERSION: 520]
# Path to PROJ shared files: /Library/Frameworks/R.framework/Versions/3.6/Resources/library/rgdal/proj
# Linking to sp version:1.4-2
# Overwritten PROJ_LIB was /Library/Frameworks/R.framework/Versions/3.6/Resources/library/rgdal/proj
# Error in ogrInfo(dsn = dsn, layer = layer, encoding = encoding, use_iconv = use_iconv, : Cannot open data source
# Traceback:
#
# 1. readOGR("X:/administrative/social_media/blogposts/json_from_R",
#  .     layer = "nys")
# 2. suppressMessages(ogr_info <- ogrInfo(dsn = dsn, layer = layer,
#  .     encoding = encoding, use_iconv = use_iconv, swapAxisOrder = swapAxisOrder,
#  .     require_geomType = require_geomType, morphFromESRI = morphFromESRI,
#  .     dumpSRS = dumpSRS))
# 3. withCallingHandlers(expr, message = function(c) invokeRestart("muffleMessage"))
# 4. ogrInfo(dsn = dsn, layer = layer, encoding = encoding, use_iconv = use_iconv,
#  .     swapAxisOrder = swapAxisOrder, require_geomType = require_geomType,
#  .     morphFromESRI = morphFromESRI, dumpSRS = dumpSRS)
